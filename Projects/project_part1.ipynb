# %%
# Dependencies
import pandas as pd

# %%
# load CSV
file_to_load = "D:\\Repos1\\gwu-arl-data-pt-09-2020-u-c\\02-Homework\\04-Python-Pandas\\03-Pandas-Project\\Mini-Project-Part-1\\Resources\\2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas
bootcamp = pd.read_csv(file_to_load)#,encoding="utf-8")
# Out:
# C:\Users\opusm\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (21,57) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Inspect all columns
bootcamp.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# 1                NaN             NaN  ...               NaN
# 2                NaN             NaN  ...               NaN
# 3                NaN             NaN  ...               NaN
# 4                NaN             NaN  ...               NaN
#
#    ResourceStackOverflow  ResourceTreehouse  ResourceUdacity  ResourceUdemy  \
# 0                    NaN                NaN              NaN            NaN
# 1                    NaN                NaN              NaN            1.0
# 2                    NaN                NaN              NaN            NaN
# 3                    NaN                NaN              NaN            NaN
# 4                    NaN                NaN              NaN            NaN
#
#    ResourceW3Schools  ResourceYouTube  \
# 0                NaN              NaN
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
#
#                               SchoolDegree              SchoolMajor  \
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN
#
#    StudentDebtOwe
# 0         20000.0
# 1             NaN
# 2             NaN
# 3          7000.0
# 4             NaN
#
# [5 rows x 113 columns]

# %%
# Extract only columns 0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111

extract = bootcamp.iloc[:,[0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]]
extract.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 0                NaN                 NaN                NaN             NaN
# 1                NaN                 NaN                NaN             NaN
# 2                NaN                 NaN                NaN             NaN
# 3                NaN                 NaN                NaN             NaN
# 4                NaN                 NaN                NaN             NaN
#
#                   CityPopulation  CodeEventBootcamp               CountryLive  \
# 0  between 100,000 and 1 million                NaN  United States of America
# 1  between 100,000 and 1 million                NaN  United States of America
# 2            more than 1 million                NaN  United States of America
# 3            more than 1 million                NaN  United States of America
# 4  between 100,000 and 1 million                NaN  United States of America
#
#                          EmploymentField    EmploymentStatus  Gender  \
# 0      office and administrative support  Employed for wages    male
# 1                      food and beverage  Employed for wages    male
# 2                                finance  Employed for wages    male
# 3  arts, entertainment, sports, or media  Employed for wages  female
# 4                              education  Employed for wages  female
#
#    HasChildren  HoursLearning   Income            JobRoleInterest  \
# 0          0.0           30.0  32000.0                        NaN
# 1          NaN           30.0  15000.0    Front-End Web Developer
# 2          NaN           20.0  48000.0                        NaN
# 3          NaN           20.0  43000.0    Front-End Web Developer
# 4          NaN           25.0   6000.0   Full-Stack Web Developer
#
#                               SchoolDegree              SchoolMajor
# 0           some college credit, no degree                      NaN
# 1           some college credit, no degree                      NaN
# 2  high school diploma or equivalent (GED)                      NaN
# 3                        bachelor's degree  Cinematography And Film
# 4           some college credit, no degree                      NaN

# %%
# Change "0" to "No" and "1" to "Yes" in response columns

#extract['AttendedBootcamp'] = extract.loc[:,extract['AttendedBootcamp' == 0.0]].replace([0.0,1.0],['No','Yes'])
extract.replace(to_replace = [0.0,1.0],value =['No','Yes'], inplace = True)

#extract.replace([0.0,'No'])
extract.tail()
# Out:
# C:\Users\opusm\anaconda3\lib\site-packages\pandas\core\frame.py:4166: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
#         Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 15615  39.0               No            NaN                  NaN
# 15616  27.0               No            NaN                  NaN
# 15617  37.0               No            NaN                  NaN
# 15618  26.0               No            NaN                  NaN
# 15619  22.0               No            NaN                  NaN
#
#       BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 15615               NaN                 NaN               NaN            NaN
# 15616               NaN                 NaN               NaN            NaN
# 15617               NaN                 NaN               NaN            NaN
# 15618               NaN                 NaN               NaN            NaN
# 15619               NaN                 NaN               NaN            NaN
#
#             CityPopulation CodeEventBootcamp               CountryLive  \
# 15615  more than 1 million               NaN                     Kenya
# 15616  more than 1 million               NaN                     India
# 15617  more than 1 million               NaN                   Nigeria
# 15618  more than 1 million               NaN                     Spain
# 15619  more than 1 million               NaN  United States of America
#
#                              EmploymentField          EmploymentStatus  \
# 15615            software development and IT  Self-employed freelancer
# 15616            software development and IT        Employed for wages
# 15617                                    NaN  Self-employed freelancer
# 15618                              education  Self-employed freelancer
# 15619  arts, entertainment, sports, or media        Employed for wages
#
#        Gender HasChildren HoursLearning   Income            JobRoleInterest  \
# 15615    male          No            40  10000.0                        NaN
# 15616    male          No            15  10000.0    Front-End Web Developer
# 15617    male         NaN            14  48000.0                        NaN
# 15618    male         NaN            10  10000.0                        NaN
# 15619  female          No             2  18000.0                        NaN
#
#                              SchoolDegree             SchoolMajor
# 15615                   bachelor's degree               Chemistry
# 15616                   bachelor's degree  Electrical Engineering
# 15617                   bachelor's degree               Chemistry
# 15618  master's degree (non-professional)                    Math
# 15619                   bachelor's degree          Graphic Design

# %%
# Calculate total number of respondents in survey
respondents = len(extract) 
rowcount= extract.count()
respondents, rowcount
# Out:
# (15620,
#  Age                     13613
#  AttendedBootcamp        15380
#  BootcampFinish            933
#  BootcampFullJobAfter      635
#  BootcampLoanYesNo         934
#  BootcampPostSalary        330
#  BootcampRecommend         937
#  ChildrenNumber           2554
#  CityPopulation          13630
#  CodeEventBootcamp          42
#  CountryLive             13610
#  EmploymentField          7608
#  EmploymentStatus        12904
#  Gender                  13746
#  HasChildren              4012
#  HoursLearning           14942
#  Income                   7329
#  JobRoleInterest          6503
#  SchoolDegree            13679
#  SchoolMajor              8450
#  dtype: int64)

# %%
# Extract rows corresponding only to people who attended a bootcamp
attended = extract.loc[(extract['AttendedBootcamp']  == 'Yes')]
attended.head()
# Out:
#       Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93   32.0              Yes            Yes                   No
# 97   26.0              Yes            Yes                  Yes
# 130  41.0              Yes            Yes                  Yes
# 159  26.0              Yes            Yes                   No
# 188  24.0              Yes             No                  NaN
#
#     BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 93                 No                 NaN                No            NaN
# 97                 No             45000.0                No            NaN
# 130               Yes             75000.0               Yes              3
# 159                No                 NaN                No            NaN
# 188               Yes                 NaN                No            NaN
#
#                     CityPopulation CodeEventBootcamp  \
# 93   between 100,000 and 1 million               NaN
# 97             more than 1 million               NaN
# 130              less than 100,000               NaN
# 159  between 100,000 and 1 million               NaN
# 188  between 100,000 and 1 million               NaN
#
#                   CountryLive                        EmploymentField  \
# 93   United States of America  arts, entertainment, sports, or media
# 97   United States of America                   software development
# 130  United States of America                   software development
# 159  United States of America                                    NaN
# 188                    Canada                                    NaN
#
#                          EmploymentStatus  Gender HasChildren HoursLearning  \
# 93           Self-employed business owner    male         NaN            20
# 97                     Employed for wages    male          No            10
# 130                    Employed for wages    male         Yes            30
# 159  Not working and not looking for work  female         NaN            30
# 188      Not working but looking for work  female         NaN            60
#
#       Income           JobRoleInterest                        SchoolDegree  \
# 93   67000.0                       NaN                   bachelor's degree
# 97   40000.0                       NaN  master's degree (non-professional)
# 130  75000.0                       NaN      some college credit, no degree
# 159      NaN  Full-Stack Web Developer      some college credit, no degree
# 188      NaN                       NaN      some college credit, no degree
#
#     SchoolMajor
# 93      Biology
# 97        Music
# 130         NaN
# 159         NaN
# 188         NaN

# %%
attendees = attended['AttendedBootcamp'].count()
attendees
# Out:
# 953

# %%
# Calculate average age of attendees
# Calculate how many people attended a bootcamp
# Calculate how many attendees hold degrees
# Count number of attendees who self-identify as male; female; or are of non-binary gender identification
# Calculate percentage of respondents who attended a bootcamp
# Calculate percentage of respondents belonging to each gender
# Calculate percentage of attendees with a school degree
# Calculate average post-bootcamp salary

# %%
# Calculate average age of attendees
aveage = round(attended['Age'].mean(),3)
aveage
# Out:
# 31.066

# %%
# Calculate how many people attended a bootcamp
attendees = attended['AttendedBootcamp'].count()
attendees
# Out:
# 953

# %%
# Calculate how many attendees hold degrees
#run valuecounts to check kinds of degrees
degree = attended.loc[attended['AttendedBootcamp'] == 'Yes','SchoolDegree'].value_counts()

#create list of degrees
wdegrees = ["bachelor's degree","master's degree (non-professional)", 'professional degree (MBA, MD, JD, etc.)',"associate's degree",'Ph.D.']

#create new table based on "isin" wdegrees list filter
newdf = attended[attended.SchoolDegree.isin(wdegrees)]
wdegreescount = newdf['AttendedBootcamp'].count()
wdegreescount
# Out:
# 637

# %%
# Count number of attendees who self-identify as male; female; or are of non-binary gender identification
male = attended.loc[attended["Gender"] == "male","AttendedBootcamp"].count()
female = attended.loc[attended["Gender"] == "female","AttendedBootcamp"].count()
others = attended['Gender'].count() - male - female
male, female, others
# Out:
# (496, 326, 11)

# %%
# Calculate percentage of respondents who attended a bootcamp
didattend = round((attendees / respondents)*100,2)

#formatting
didattend = "{:.2f}%".format(didattend)
didattend
# Out:
# '6.10%'

# %%
# Calculate percentage of respondents belonging to each gender
malepct = round((male/respondents) * 100,2)
femalepct = round((female/respondents) * 100,2)
othpct = round((others/respondents) * 100,2)
#formatting
malepct = "{:.2f}%".format(malepct)
femalepct = "{:.2f}%".format(femalepct)
othpct = "{:.2f}%".format(othpct)
malepct, femalepct, othpct
# Out:
# ('3.18%', '2.09%', '0.07%')

# %%
# Calculate percentage of attendees with a school degree

degreepct = round((wdegreescount/attendees) * 100,2)
"{:.2f}%".format(degreepct)
# Out:
# '66.84%'

# %%
# Calculate average post-bootcamp salary
salary = attended['BootcampPostSalary'].mean()
#formatting
salary = "${:,.2f}".format(salary)
salary
# Out:
# '$63,740.51'

# %%
# Create a new table consolodating above calculations
summary = pd.DataFrame({})

# %%
# Improve formatting before outputting spreadsheet

# %%
# Export to Excel
